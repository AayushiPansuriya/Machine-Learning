# %%
#Edge detection..
import cv2
import matplotlib.pyplot as plt

#loading an image
img=cv2.imread('tiger.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #edge detection works on intensity value,not on color.so BGR2GRAY is used.

#sobel(src,ddepth,x,y,kernel_size)
sobelx=cv2.Sobel(img,cv2.CV_64F,1,0,10)
sobely=cv2.Sobel(img,cv2.CV_64F,0,1,10)
sobel_combined=cv2.magnitude(sobelx, sobely) #magnitued combinesx strong edges from sobel-x and sobel-y

#ploting the image
plt.figure(figsize=(10,6))
plt.subplot(1,4,1),plt.imshow(img),plt.title('source image'),plt.axis('off')
plt.subplot(1,4,2),plt.imshow(sobelx,cmap='gray'),plt.title('sobel-x'),plt.axis('off')
plt.subplot(1,4,3),plt.imshow(sobely,cmap='gray'),plt.title('sobel-y'),plt.axis('off')
plt.subplot(1,4,4),plt.imshow(sobel_combined,cmap='gray'),plt.title('sobel_combined'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'sobel_combined'}>,
#  <matplotlib.image.AxesImage at 0x1c22cb93ee0>,
#  Text(0.5, 1.0, 'sobel_combined'),
#  (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5)))

# %%
#Edge detection..
import cv2
import matplotlib.pyplot as plt

#loading an image
img=cv2.imread('img1.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#blurring an image using gaussian blur
gauss=cv2.GaussianBlur(img,(3,3),0)

#laplacian(src,ddepth,kernel-size)
laplacian=cv2.Laplacian(img,cv2.CV_64F,ksize=3)
laplacian_after_blur=cv2.Laplacian(gauss,cv2.CV_64F,ksize=3)

#ploting the image
plt.figure(figsize=(10,6))
plt.subplot(1,4,1),plt.imshow(img),plt.title('source image'),plt.axis('off')
plt.subplot(1,4,2),plt.imshow(laplacian,cmap='gray'),plt.title('lap'),plt.axis('off')
plt.subplot(1,4,3),plt.imshow(laplacian_after_blur,cmap='gray'),plt.title('lap_gray'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'lap_gray'}>,
#  <matplotlib.image.AxesImage at 0x1c22eff26e0>,
#  Text(0.5, 1.0, 'lap_gray'),
#  (np.float64(-0.5), np.float64(243.5), np.float64(147.5), np.float64(-0.5)))

# %%
#Edge detection..
import cv2
import matplotlib.pyplot as plt

#loading an image
img=cv2.imread('img3.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#blurring an image using gaussian blur
gauss=cv2.GaussianBlur(img,(3,3),0)

#canny(src,threshold1,threshold2)
canny=cv2.Canny(img,threshold1=30,threshold2=500)
canny_after_blur=cv2.Canny(gauss,threshold1=20,threshold2=200)

#ploting the image
plt.figure(figsize=(10,6))
plt.subplot(1,3,1),plt.imshow(img),plt.title('source image'),plt.axis('off')
plt.subplot(1,3,2),plt.imshow(canny,cmap='gray'),plt.title('canny'),plt.axis('off')
plt.subplot(1,3,3),plt.imshow(canny_after_blur,cmap='gray'),plt.title('canny_after_blur'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'canny_after_blur'}>,
#  <matplotlib.image.AxesImage at 0x1c22cc27c40>,
#  Text(0.5, 1.0, 'canny_after_blur'),
#  (np.float64(-0.5), np.float64(299.5), np.float64(167.5), np.float64(-0.5)))
