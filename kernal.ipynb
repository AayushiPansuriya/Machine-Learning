# %%
#bluring an image
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('img3.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.ones((4,4),np.float32)/16
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x259eaf02290>,
#  (np.float64(-0.5), np.float64(299.5), np.float64(167.5), np.float64(-0.5)))

# %%
#KERNAL
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('img5.WEBP')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# k1=np.array([[0,0,0],[0,9,0],[0,0,0]])
# img1=cv2.filter2D(img,-1,k1)
k2=np.array([[-1,-1,-1],[-1,10,-1,],[-1,-1,-1]])
img1=cv2.filter2D(img,-1,k2)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x259eea0bdf0>,
#  (np.float64(-0.5), np.float64(422.5), np.float64(279.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('img1.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[0,0,0],[0,0.8,0],[0,0,0]])
img1=cv2.filter2D(img,-1,k1)
# k2=np.array([[-1,-1,-1],[-1,3,-1,],[-1,-1,-1]])
# img1=cv2.filter2D(img,-1,k2)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x259eb4ee5c0>,
#  (np.float64(-0.5), np.float64(243.5), np.float64(147.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('img4.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[0,0,0],[0,1.4,0],[0,0,0]])
img1=cv2.filter2D(img,-1,k1)
# k2=np.array([[-1,-1,-1],[-1,9,-1,],[-1,-1,-1]])
# img1=cv2.filter2D(img,-1,k2)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x259eeb627a0>,
#  (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('img6.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[0,0,-1],[0,0,5],[0,1,-1]])
img1=cv2.filter2D(img,-1,k1)
# k2=np.array([[-1,-1,-1],[-1,9,-1,],[-1,-1,-1]])
# img1=cv2.filter2D(img,-1,k2)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x259f18ebf40>,
#  (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5)))
